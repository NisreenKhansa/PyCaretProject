# %%
# !pip install pycaret

from pycaret.datasets import get_data
data= get_data ("blood")
# Out:
# ...
#    Recency  Frequency  Monetary  Time  Class
# 0        2         50     12500    98      1
# 1        0         13      3250    28      1
# 2        1         16      4000    35      1
# 3        2         20      5000    45      1
# 4        1         24      6000    77      0

# %%
blood = get_data('blood')
# Out:
#    Recency  Frequency  Monetary  Time  Class
# 0        2         50     12500    98      1
# 1        0         13      3250    28      1
# 2        1         16      4000    35      1
# 3        2         20      5000    45      1
# 4        1         24      6000    77      0

# %%
data.shape
# Out:
# (748, 5)

# %%
data.columns
# Out:
# Index(['Recency', 'Frequency', 'Monetary', 'Time', 'Class'], dtype='object')

# %%
data.size
# Out:
# 3740

# %%
748*5
# Out:
# 3740

# %%
data.head()
# Out:
#    Recency  Frequency  Monetary  Time  Class
# 0        2         50     12500    98      1
# 1        0         13      3250    28      1
# 2        1         16      4000    35      1
# 3        2         20      5000    45      1
# 4        1         24      6000    77      0

# %%
data.tail()
# Out:
#      Recency  Frequency  Monetary  Time  Class
# 743       23          2       500    38      0
# 744       21          2       500    52      0
# 745       23          3       750    62      0
# 746       39          1       250    39      0
# 747       72          1       250    72      0

# %%
data.describe()
# Out:
#           Recency   Frequency      Monetary        Time       Class
# count  748.000000  748.000000    748.000000  748.000000  748.000000
# mean     9.506684    5.514706   1378.676471   34.282086    0.237968
# std      8.095396    5.839307   1459.826781   24.376714    0.426124
# min      0.000000    1.000000    250.000000    2.000000    0.000000
# 25%      2.750000    2.000000    500.000000   16.000000    0.000000
# 50%      7.000000    4.000000   1000.000000   28.000000    0.000000
# 75%     14.000000    7.000000   1750.000000   50.000000    0.000000
# max     74.000000   50.000000  12500.000000   98.000000    1.000000

# %%
blood = get_data('blood')
# Out:
#    Recency  Frequency  Monetary  Time  Class
# 0        2         50     12500    98      1
# 1        0         13      3250    28      1
# 2        1         16      4000    35      1
# 3        2         20      5000    45      1
# 4        1         24      6000    77      0

# %%
blood.columns
# Out:
# Index(['Recency', 'Frequency', 'Monetary', 'Time', 'Class'], dtype='object')

# %%
blood.head()
# Out:
#    Recency  Frequency  Monetary  Time  Class
# 0        2         50     12500    98      1
# 1        0         13      3250    28      1
# 2        1         16      4000    35      1
# 3        2         20      5000    45      1
# 4        1         24      6000    77      0

# %%
blood.describe()
# Out:
#           Recency   Frequency      Monetary        Time       Class
# count  748.000000  748.000000    748.000000  748.000000  748.000000
# mean     9.506684    5.514706   1378.676471   34.282086    0.237968
# std      8.095396    5.839307   1459.826781   24.376714    0.426124
# min      0.000000    1.000000    250.000000    2.000000    0.000000
# 25%      2.750000    2.000000    500.000000   16.000000    0.000000
# 50%      7.000000    4.000000   1000.000000   28.000000    0.000000
# 75%     14.000000    7.000000   1750.000000   50.000000    0.000000
# max     74.000000   50.000000  12500.000000   98.000000    1.000000

# %%
blood ['Class'].value_counts()
# Out:
# 0    570
# 1    178
# Name: Class, dtype: int64

# %%
from pycaret.classification import *

s = setup(data=blood, target='Class')
# Out:
# <style type="text/css">
# #T_ac659_row8_col1 {
#   background-color: lightgreen;
# }
# </style>
# <table id="T_ac659" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_ac659_level0_col0" class="col_heading level0 col0" >Description</th>
#       <th id="T_ac659_level0_col1" class="col_heading level0 col1" >Value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_ac659_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_ac659_row0_col0" class="data row0 col0" >Session id</td>
#       <td id="T_ac659_row0_col1" class="data row0 col1" >5615</td>
#     </tr>
#     <tr>
#       <th id="T_ac659_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_ac659_row1_col0" class="data row1 col0" >Target</td>
#       <td id="T_ac659_row1_col1" class="data row1 col1" >Class</td>
#     </tr>
#     <tr>
#       <th id="T_ac659_level0_row2" class="row_heading level0 row2" >2</th>
# ...

# %%
best = compare_models()
# Out:
# <style type="text/css">
# #T_f84fa th {
#   text-align: left;
# }
# ...

# %%
evaluate_model(best)
# Out:
# interactive(children=(ToggleButtons(description='Plot Type:', icons=('',), options=(('Pipeline Plot', 'pipelin…

# %%
predict_model(best, data)
# Out:
# <style type="text/css">
# </style>
# <table id="T_eb4db" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_eb4db_level0_col0" class="col_heading level0 col0" >Model</th>
#       <th id="T_eb4db_level0_col1" class="col_heading level0 col1" >Accuracy</th>
#       <th id="T_eb4db_level0_col2" class="col_heading level0 col2" >AUC</th>
#       <th id="T_eb4db_level0_col3" class="col_heading level0 col3" >Recall</th>
#       <th id="T_eb4db_level0_col4" class="col_heading level0 col4" >Prec.</th>
#       <th id="T_eb4db_level0_col5" class="col_heading level0 col5" >F1</th>
#       <th id="T_eb4db_level0_col6" class="col_heading level0 col6" >Kappa</th>
#       <th id="T_eb4db_level0_col7" class="col_heading level0 col7" >MCC</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_eb4db_level0_row0" class="row_heading level0 row0" >0</th>
# ...

# %%
save_model (best, 'nisreen_model')
# Out:
# Transformation Pipeline and Model Successfully Saved
# (Pipeline(memory=Memory(location=None),
#           steps=[('numerical_imputer',
#                   TransformerWrapper(exclude=None,
#                                      include=['Recency', 'Frequency', 'Monetary',
#                                               'Time'],
#                                      transformer=SimpleImputer(add_indicator=False,
#                                                                copy=True,
#                                                                fill_value=None,
#                                                                keep_empty_features=False,
#                                                                missing_values=nan,
#                                                                strategy='mean',
#                                                                verbose='deprecated'))),
#                  ('categorical_imputer',
# ...

# %%
print(best)
# Out:
# AdaBoostClassifier(algorithm='SAMME.R', base_estimator='deprecated',
#                    estimator=None, learning_rate=1.0, n_estimators=50,
#                    random_state=5615)
